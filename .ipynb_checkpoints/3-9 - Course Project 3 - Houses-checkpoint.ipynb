# %% [markdown]
# # Import libraries
# ----------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

## Scikit-learn
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import PolynomialFeatures

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso


from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE

from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Import dataset
# -----------------------

# %%
data_df = pd.read_csv('house-prices.csv')
data_df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    484  528275070           60        RL           NaN      8795   Pave
# 1   2586  535305120           20        RL          75.0     10170   Pave
# 2   2289  923228250          160        RM          21.0      2001   Pave
# 3    142  535152150           20        RL          70.0     10552   Pave
# 4   2042  903475060          190        RM          60.0     10120   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 3   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Bnk  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#
# # First glance at the data set
# ------------------------

# %%
data_df.shape
# Out:
# (2430, 82)

# %%
data_df.describe()
# Out:
#              Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2430.000000  2.430000e+03  2430.000000   2010.000000    2430.000000
# mean   1469.478189  7.149375e+08    57.092593     69.201990   10243.557613
# std     843.236520  1.887339e+08    42.903254     23.486988    8353.925254
# min       1.000000  5.263011e+08    20.000000     21.000000    1470.000000
# 25%     749.250000  5.284770e+08    20.000000     58.000000    7482.000000
# 50%    1470.500000  5.354541e+08    50.000000     68.000000    9500.000000
# 75%    2193.500000  9.071352e+08    70.000000     80.000000   11604.500000
# max    2930.000000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2430.000000   2430.000000  2430.000000     2430.000000   2410.000000
# mean       6.088889      5.569959  1971.167490     1984.238683    101.995436
# ...

# %% [markdown]
# ### Order, PID and MS SubClass are not "numerous" data, they're rather "id" date. We can consider them as "strings"

# %%
# data_df['Order'] = str(data_df['Order'])
# data_df['PID'] = str(data_df['PID'])
# data_df['MS SubClass'] = str(data_df['MS SubClass'])
# data_df.drop('Order', axis = 1);
# data_df.drop('PID', axis = 1);

data_df.describe()
# Out:
#              Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2430.000000  2.430000e+03  2430.000000   2010.000000    2430.000000
# mean   1469.478189  7.149375e+08    57.092593     69.201990   10243.557613
# std     843.236520  1.887339e+08    42.903254     23.486988    8353.925254
# min       1.000000  5.263011e+08    20.000000     21.000000    1470.000000
# 25%     749.250000  5.284770e+08    20.000000     58.000000    7482.000000
# 50%    1470.500000  5.354541e+08    50.000000     68.000000    9500.000000
# 75%    2193.500000  9.071352e+08    70.000000     80.000000   11604.500000
# max    2930.000000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2430.000000   2430.000000  2430.000000     2430.000000   2410.000000
# mean       6.088889      5.569959  1971.167490     1984.238683    101.995436
# ...

# %% [markdown]
# ### Type of data
# ----------------

# %% [markdown]
# #### Let's create a list of different type of columns based on the description.txt. I chose to include discrete data like n° of rooms or garage cars in the ordinal column as it can be considered the higher the better

# %%
# Define list of columns 
continuous_col = ['SalePrice','Lot Frontage','Lot Area', 'Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Unf SF','Total Bsmt SF','1st Flr SF','2nd Flr SF','Low Qual Fin SF','Gr Liv Area','Garage Area','Wood Deck SF','Open Porch SF','Enclosed Porch','3Ssn Porch','Screen Porch','Pool Area','Misc Val']
continuous_col_ex_y = ['Lot Frontage','Lot Area', 'Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Unf SF','Total Bsmt SF','1st Flr SF','2nd Flr SF','Low Qual Fin SF','Gr Liv Area','Garage Area','Wood Deck SF','Open Porch SF','Enclosed Porch','3Ssn Porch','Screen Porch','Pool Area','Misc Val']
ordinal_col = ['Lot Shape','Utilities','Land Slope','Overall Qual','Overall Cond','Exter Qual','Exter Cond','Bsmt Qual','Bsmt Cond','Bsmt Exposure','BsmtFin Type 1','BsmtFin Type 2','Heating QC','Electrical','Kitchen Qual','Functional','Fireplace Qu','Garage Finish','Garage Qual','Garage Cond','Paved Drive','Pool QC','Fence','Bsmt Full Bath','Bsmt Half Bath','Full Bath','Half Bath','Bedroom AbvGr','Kitchen AbvGr','TotRms AbvGrd','Fireplaces','Garage Cars']
yr_col = ['Year Built','Year Remod/Add','Garage Yr Blt','Yr Sold','Mo Sold']
nominal_col = ['MS SubClass','MS Zoning','Street','Alley','Land Contour','Lot Config','Neighborhood','Condition 1','Condition 2','Bldg Type','House Style','Roof Style','Roof Matl','Exterior 1st','Exterior 2nd','Mas Vnr Type','Foundation','Heating','Central Air','Garage Type','Misc Feature','Sale Type','Sale Condition']

# %%
print(len(continuous_col))
print(len(ordinal_col))
print(len(nominal_col))
print(len(yr_col))
# Out:
# 20
# 32
# 23
# 5

# %%
# checking columns consistency (no need to work on Order and PID) and Sales Price is the output.

all_col = continuous_col_ex_y + ordinal_col + nominal_col + yr_col
nb = 0
for x in data_df.columns:
    nb += 1
    if x not in all_col:
        print(x)
# Out:
# Order
# PID
# SalePrice

# %%
data_df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
# Print each value for all ordinal columns
for col in ordinal_col:
    print(col,' :',data_df[col].unique())
# Out:
# Lot Shape  : ['IR1' 'Reg' 'IR2' 'IR3']
# Utilities  : ['AllPub' 'NoSewr' 'NoSeWa']
# Land Slope  : ['Gtl' 'Mod' 'Sev']
# Overall Qual  : [ 7  6  4  5  8  9 10  3  1  2]
# Overall Cond  : [5 6 4 8 7 1 9 3 2]
# Exter Qual  : ['Gd' 'TA' 'Fa' 'Ex']
# Exter Cond  : ['TA' 'Gd' 'Fa' 'Ex' 'Po']
# Bsmt Qual  : ['Gd' 'TA' 'Ex' nan 'Fa' 'Po']
# Bsmt Cond  : ['TA' 'Gd' 'Fa' nan 'Ex' 'Po']
# Bsmt Exposure  : ['No' 'Av' 'Mn' 'Gd' nan]
# BsmtFin Type 1  : ['GLQ' 'Unf' 'Rec' 'LwQ' 'BLQ' 'ALQ' nan]
# BsmtFin Type 2  : ['Unf' 'LwQ' 'BLQ' nan 'Rec' 'ALQ' 'GLQ']
# Heating QC  : ['Ex' 'TA' 'Fa' 'Gd' 'Po']
# Electrical  : ['SBrkr' 'FuseF' 'FuseA' 'FuseP' nan 'Mix']
# Kitchen Qual  : ['Gd' 'TA' 'Ex' 'Fa' 'Po']
# Functional  : ['Typ' 'Mod' 'Maj1' 'Min2' 'Min1' 'Maj2' 'Sal' 'Sev']
# Fireplace Qu  : ['TA' 'Gd' nan 'Fa' 'Po' 'Ex']
# Garage Finish  : ['Fin' 'Unf' 'RFn' nan]
# Garage Qual  : ['TA' 'Fa' nan 'Gd' 'Ex' 'Po']
# Garage Cond  : ['TA' nan 'Fa' 'Gd' 'Ex' 'Po']
# Paved Drive  : ['Y' 'N' 'P']
# ...

# %% [markdown]
# ### We will later in the project encode the values for Ordinal Values with integer scale in a Pipeline and one-hote encoding for Nominal columns

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#
# # Data Cleaning
# ----------------

# %% [markdown]
# ### Missing Values

# %%
data_df.isnull().sum().sort_values(ascending=False)
# Out:
# Pool QC            2418
# Misc Feature       2340
# Alley              2267
# Fence              1941
# Fireplace Qu       1186
# Lot Frontage        420
# Garage Qual         138
# Garage Yr Blt       138
# Garage Cond         138
# Garage Finish       138
# Garage Type         136
# Bsmt Exposure        74
# BsmtFin Type 2       72
# BsmtFin Type 1       71
# Bsmt Cond            71
# Bsmt Qual            71
# Mas Vnr Type         20
# Mas Vnr Area         20
# Bsmt Full Bath        2
# Bsmt Half Bath        2
# Garage Area           1
# Garage Cars           1
# Total Bsmt SF         1
# Bsmt Unf SF           1
# BsmtFin SF 2          1
# BsmtFin SF 1          1
# Electrical            1
# Exterior 2nd          0
# Exterior 1st          0
# Roof Matl             0
#                    ...
# Heating               0
# Exter Cond            0
# Functional            0
# Sale Type             0
# Yr Sold               0
# Mo Sold               0
# Misc Val              0
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#     Based on the description.txt, what can we do with missing values :
#
#
#
# **REPLACE NaN by ordinal or nominal "NA" which exists in the description :**
# - Alley makes sense to be NA if they have no alleyway
# - Pool QC makes sense to be NA if they have no pool "Pool Area" == 0
# - Misc Feature
# - Fireplace Qu
# - Fence
# - Garage Type
# - Garage Qual
# - Garage Finish
# - Garage Cond
# - Bsmt Exposure (no basement in this property)
# - BsmtFin Type 2 (no basement in this property)
# - BsmtFin Type 1 (no basement in this property)
# - Bsmt Cond (no basement in this property)
# - Bsmt Qual (no basement in this property)
# - Mas Vnr Type (replace by None)
#
# **REPLACE by another value :**
# - Lot Frontage (the minimum is not 0, so we can consider every property to have at least a street connected to it, we will take the mean or median which are pretty close)
# - Electrical (replace by SBrkr - most common feature)
#
# **REPLACE by 0 :**
# - Mas Vnr Area
# - Garage Area
# - Garage Cars
# - Bsmt Full Bath
# - Bsmt Half Bath
# - Total Bsmt SF
# - Bsmt Unf SF
# - BsmtFin SF 2
# - BsmtFin SF 1
#
#
# **LEAVE with NaN :**
# - Garage Yr Blt, no need to replace as no garages is built, no year can be chosen for the same 138 properties

# %%
# List of all these columns
col_with_nan = data_df.loc[:,data_df.isnull().sum() > 0].columns
col_with_nan
# Out:
# Index(['Lot Frontage', 'Alley', 'Mas Vnr Type', 'Mas Vnr Area', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Electrical', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Fireplace Qu',
#        'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Garage Qual', 'Garage Cond', 'Pool QC', 'Fence',
#        'Misc Feature'],
#       dtype='object')

# %%
# Replace NaN by NA
col_nan_to_na = [x for x in col_with_nan if x not in ['Electrical','Lot Frontage','Mas Vnr Area','Garage Area','Garage Cars', 'Garage Yr Blt','Bsmt Full Bath','Bsmt Half Bath','Total Bsmt SF','Bsmt Unf SF','BsmtFin SF 2','BsmtFin SF 1']]

for col in col_nan_to_na:
    if col == 'Mas Vnr Type':
        data_df[col] = data_df[col].fillna('None')
    else:
        data_df[col] = data_df[col].fillna('NA') # replace by existing "NA" in documentation

# %%
# Replace NaN by 0

for col in ['Mas Vnr Area','Garage Area','Garage Cars', 'Bsmt Full Bath','Bsmt Half Bath','Total Bsmt SF','Bsmt Unf SF','BsmtFin SF 2','BsmtFin SF 1']:
    data_df[col] = data_df[col].fillna(0) # replace by 0 as it represents a "number"

# %%
# Replace NaN by 0

for col in ['Mas Vnr Area','Garage Area','Garage Cars', 'Bsmt Full Bath','Bsmt Half Bath','Total Bsmt SF','Bsmt Unf SF','BsmtFin SF 2','BsmtFin SF 1']:
    data_df[col] = data_df[col].fillna(0) # replace by 0 as it represents a "number"

# Replace NaN by other value 

# by most frequent value
data_df['Electrical'] = data_df['Electrical'].fillna(data_df['Electrical'].value_counts().idxmax())

# by median value
data_df['Lot Frontage'] = data_df['Lot Frontage'].fillna(data_df['Lot Frontage'].median())

# by "No garage"
data_df['Garage Yr Blt'] = data_df['Garage Yr Blt'].fillna(0)

# %%
# Check null values in dataframe

data_df.isnull().sum().sort_values(ascending=False).head()
# Out:
# SalePrice       0
# Year Built      0
# Roof Style      0
# Roof Matl       0
# Exterior 1st    0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#     Missing values
# ### Eventually, we have removed all missing values.

# %% [markdown]
# ### Correct Years > 2010

# %%
for col in yr_col:
    print(col,' : between ',data_df[col].min(),' and ',data_df[col].max())
# Out:
# Year Built  : between  1875  and  2010
# Year Remod/Add  : between  1950  and  2010
# Garage Yr Blt  : between  0.0  and  2207.0
# Yr Sold  : between  2006  and  2010
# Mo Sold  : between  1  and  12

# %% [markdown]
# **We see a year at "2207", based on the rest of the data, we can suppose it is "2007"**

# %%
# Change 2207 to 2007
data_df.loc[data_df.loc[data_df['Garage Yr Blt'] == 2207].index,'Garage Yr Blt'] = 2007

#data_df['Garage Yr Blt'] = int(data_df['Garage Yr Blt'])

# Check Year range again : 
for col in yr_col:
    print(col,' : between ',data_df[col].min(),' and ',data_df[col].max())
# Out:
# Year Built  : between  1875  and  2010
# Year Remod/Add  : between  1950  and  2010
# Garage Yr Blt  : between  0.0  and  2010.0
# Yr Sold  : between  2006  and  2010
# Mo Sold  : between  1  and  12

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# The years range we can see here is more consistent and all below 2010, the end-year of the analysis.

# %% [markdown]
# ### Consistency of columns
# If there is no garage, no basement,... the other values concerning should not be filled either
# - Garage
# - Basement
# - Masonry
# - Pool
# - Fireplace

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Masonry

# %%
# Masonry columns
data_df.iloc[:, lambda df:df.columns.str.contains('Mas', case=False)].columns
# Out:
# Index(['Mas Vnr Type', 'Mas Vnr Area'], dtype='object')

# %%
# index of inconsistent values based on Description.txt
inconsistent_index = data_df.loc[(data_df['Mas Vnr Type']== 'None') & (data_df['Mas Vnr Area'] >0)].index

# %%
for i in inconsistent_index:
    data_df.iloc[i, data_df.columns.get_loc('Mas Vnr Area')] = 0

data_df.loc[(data_df['Mas Vnr Type']== 'None') & (data_df['Mas Vnr Area'] >0)] # check
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Basement

# %%
# Basement columns
bsmt_col = data_df.iloc[:, lambda df:df.columns.str.contains('Bsm', case=False)].columns

# %%
data_df.loc[(data_df['Bsmt Cond']!= 'NA') & (data_df['Bsmt Qual'] !='NA') & (data_df['Bsmt Exposure']== 'NA') ][bsmt_col]
# Out:
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 875         Gd        TA            NA            Unf           0.0
# 1681        Gd        TA            NA            Unf           0.0
# 1726        Gd        TA            NA            Unf           0.0
#
#      BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  Bsmt Full Bath  \
# 875             Unf           0.0       1595.0         1595.0             0.0
# 1681            Unf           0.0        725.0          725.0             0.0
# 1726            Unf           0.0        936.0          936.0             0.0
#
#       Bsmt Half Bath
# 875              0.0
# 1681             0.0
# 1726             0.0

# %%
# 3 Exposures at "NA" (no basement) instead "No" (no exposure)
for i in data_df.loc[(data_df['Bsmt Cond']!= 'NA') & (data_df['Bsmt Qual'] !='NA') & (data_df['Bsmt Exposure']== 'NA') ].index:
    data_df.iloc[i, data_df.columns.get_loc('Bsmt Exposure')] = "No"

# %%
for col in bsmt_col:
    print(col,' :',len(data_df.loc[(data_df[col] == 'NA') | (data_df[col] == 0)]))
# Out:
# Bsmt Qual  : 71
# Bsmt Cond  : 71
# Bsmt Exposure  : 71
# BsmtFin Type 1  : 71
# BsmtFin SF 1  : 774
# BsmtFin Type 2  : 72
# BsmtFin SF 2  : 2136
# Bsmt Unf SF  : 211
# Total Bsmt SF  : 71
# Bsmt Full Bath  : 1414
# Bsmt Half Bath  : 2287
# C:\Users\lyeso\anaconda3\envs\exts-ml\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
# Check if total Basement Square Feet = the sum of all surfaces
data_df.loc[(data_df['Total Bsmt SF']) != (data_df['Bsmt Unf SF']+data_df['BsmtFin SF 1']+data_df['BsmtFin SF 2'])][bsmt_col]
# Out:
# Empty DataFrame
# Columns: [Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Bsmt Full Bath, Bsmt Half Bath]
# Index: []

# %% [markdown]
# **Eventually, Basement Columns look consistent to one another and possibly only 71 properties without Basements.**

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Fireplace

# %%
# Fireplace columns
fire_col = data_df.iloc[:, lambda df:df.columns.str.contains('Fire', case=False)].columns
fire_col
# Out:
# Index(['Fireplaces', 'Fireplace Qu'], dtype='object')

# %%
data_df.loc[(data_df['Fireplaces'] != 0) & (data_df['Fireplace Qu'] =='NA') ][fire_col]
# Out:
# Empty DataFrame
# Columns: [Fireplaces, Fireplace Qu]
# Index: []

# %%
for col in fire_col:
    print(col,' :',len(data_df.loc[(data_df[col] == 'NA') | (data_df[col] == 0)]))
# Out:
# Fireplaces  : 1186
# Fireplace Qu  : 1186

# %% [markdown]
# **Fireplace are consistent to one another, half of the properties don't have them.**

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Garage

# %%
# Garage columns
garage_col = data_df.iloc[:, lambda df:df.columns.str.contains('Gara', case=False)].columns
garage_col
# Out:
# Index(['Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Garage Qual', 'Garage Cond'],
#       dtype='object')

# %%
for col in garage_col:
    print(col,' :',len(data_df.loc[(data_df[col] == 'NA') | (data_df[col] == 0) | (data_df[col].isnull())]))
# Out:
# Garage Type  : 136
# Garage Yr Blt  : 138
# Garage Finish  : 138
# Garage Cars  : 137
# Garage Area  : 137
# Garage Qual  : 138
# Garage Cond  : 138

# %% [markdown]
# **Garage are fairly consistent to one another, half of the properties don't have them.**
# Only one missing Garage Type

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Pool

# %%
# Garage columns
pool_col = data_df.iloc[:, lambda df:df.columns.str.contains('Pool', case=False)].columns
pool_col
# Out:
# Index(['Pool Area', 'Pool QC'], dtype='object')

# %%
for col in pool_col:
    print(col,' :',len(data_df.loc[(data_df[col] == 'NA') | (data_df[col] == 0)]))
# Out:
# Pool Area  : 2418
# Pool QC  : 2418

# %%
# Print each value for all pool columns
for col in pool_col:
    print(col,' :',data_df[col].unique())
# Out:
# Pool Area  : [  0 648 555 228 144 519 561 480 512 576 444 800 368]
# Pool QC  : ['NA' 'Fa' 'Ex' 'TA' 'Gd']

# %% [markdown]
# **Most houses don't have a Pool, but it can still be relevant for the price**

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Outliers for continuous data
# ---------------------------
# Quick look at the distribution with $np.log1p()$

# %%
# 20 subplots of all continuous data
fig, axes = plt.subplots(
    10, 4 ,gridspec_kw={"height_ratios": (0.8, 0.2, 0.8, 0.2, 0.8, 0.2, 0.8, 0.2, 0.8 ,0.2)}, figsize=(15,23)
)
# pairing feature with column in plot
for row, i in zip([0,2,4,6,8],[0,1,2,3,4])  :

    for (feat, plot_col) in zip(continuous_col[0+4*i:4+4*i], [0,1,2,3]  ):

        axes[0+row, plot_col].hist(np.log1p(data_df[feat]), bins=50)
        axes[0+row, plot_col].set_title("{}".format(feat))
        sns.despine(ax=axes[0+row, plot_col])
        sns.boxplot(np.log1p(data_df[feat]), ax=axes[1+row, plot_col], fliersize=2)
        axes[1+row, plot_col].set(yticks=[])
        #axes[1+row, plot_col].set_title("{}".format(data_df[feat].median))
        sns.despine(ax=axes[1+row, plot_col], left=True)

    for ax in axes.flatten():
        ax.set_xlabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### My feeling about what I would mathematically consider outliers with z-score, would impact the Sales Price greatly.
# For example, houses with a pool or a 3-Season Porch are z-score outliers but at the same time, are probably more expensive and impacted by the presence of a pool.
#
# I am not convinced a mathematical outlier removal makes sense, I would rather check "visually" those outliers. Indeed, many outliers could be specific case.
#
# ### First let's try z-score on each column excluding the 0

# %% [markdown]
# ### Rather than calcuating outliers on the Price, I think more fit to use the **Price per square feet** for outliers in this manner.

# %%
data_df['Price SF'] = data_df['SalePrice'] / data_df['Gr Liv Area']
data_df['Price SF'].describe()
# Out:
# count    2430.000000
# mean      121.526262
# std        32.285616
# min        15.371394
# 25%       100.142230
# 50%       120.376954
# 75%       139.885283
# max       276.250881
# Name: Price SF, dtype: float64

# %%
# Create a list of continuous columns on which we will look for outliers
column_for_outliers = continuous_col.copy()
column_for_outliers.remove('SalePrice')
column_for_outliers.remove('Gr Liv Area')
column_for_outliers.append('Price SF')
column_for_outliers

# here are the columns on which we will look for outliers
# Out:
# ['Lot Frontage',
#  'Lot Area',
#  'Mas Vnr Area',
#  'BsmtFin SF 1',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  '1st Flr SF',
#  '2nd Flr SF',
#  'Low Qual Fin SF',
#  'Garage Area',
#  'Wood Deck SF',
#  'Open Porch SF',
#  'Enclosed Porch',
#  '3Ssn Porch',
#  'Screen Porch',
#  'Pool Area',
#  'Misc Val',
#  'Price SF']

# %%
# let's create a filter using the : distance to median (instead of mean to be less influenced by outliers) > 3 times standard deviation 
z_score_df = np.abs((data_df[column_for_outliers]) - (data_df[column_for_outliers].median())) > (3 * data_df[column_for_outliers].std())
print(z_score_df.sum())
print('total outliers :',z_score_df.sum().sum())
# Out:
# Lot Frontage        25
# Lot Area            24
# Mas Vnr Area        76
# BsmtFin SF 1        17
# BsmtFin SF 2        93
# Bsmt Unf SF         24
# Total Bsmt SF       20
# 1st Flr SF          27
# 2nd Flr SF          51
# Low Qual Fin SF     24
# Garage Area         13
# Wood Deck SF        87
# Open Porch SF       62
# Enclosed Porch     101
# 3Ssn Porch          28
# Screen Porch       110
# Pool Area           12
# Misc Val            17
# Price SF            20
# dtype: int64
# total outliers : 831

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#     Outliers with usual Z-Score
#
# ### As we can see, we have way too many outliers, we must be less restrictive, for example we can consider the value = 0 not to be an outlier and work only on the distributed part each value.
# For example, "Bsmt Unf SF" has a good distribution and a peak at 0. It does not mean 0 is an outlier, but on the distributed SF we can find them.
#
# Let's modify our zscore formula to not include "zeros" in the calculation

# %%
# z_score including 0
zero_filter = data_df[column_for_outliers] != 0
zero_filter

# z_score
z_score = np.abs((data_df[zero_filter][column_for_outliers]) - (data_df[zero_filter][column_for_outliers].median())) / ((data_df[zero_filter][column_for_outliers].std()))

z_score_df_excl_0 = z_score > 3

# %%
z_score_df_excl_0.sum().sum()
# Out:
# 263

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#     Adapted Z-Score
#
# ### As we can see with that "0" filter, we have way less outliers as the "common zeros" are not in it anymore.

# %%
# Create a function to drop rows on a boolean condition (here the test for zfilter): 

def drop_outliers(df, list_column, threshold):
    df=df.copy()
    
    #loop function for each column
    for column in list_column:
        df = df.drop(df.loc[np.abs(df[zero_filter][column] - df[zero_filter][column].median()) > threshold *(df[zero_filter][column].std())].index, axis = 0)    
    return df

# %%
# without outliers
data_df_wo = drop_outliers(data_df, column_for_outliers, 3)
print(data_df.shape,'rows, columns initially vs. ',data_df_wo.shape,' after outliers removal')
# Out:
# (2430, 83) rows, columns initially vs.  (2218, 83)  after outliers removal

# %% [markdown]
# ### We dropped about 200 rows ~10 % of houses

# %%
# 20 subplots of all continuous data
fig, axes = plt.subplots(
    10, 4 ,gridspec_kw={"height_ratios": (0.8, 0.2, 0.8, 0.2, 0.8, 0.2, 0.8, 0.2, 0.8 ,0.2)}, figsize=(15,23)
)
# pairing feature with column in plot
for row, i in zip([0,2,4,6,8],[0,1,2,3,4])  :

    for (feat, plot_col) in zip(column_for_outliers[0+4*i:4+4*i], [0,1,2,3]  ):

        axes[0+row, plot_col].hist(data_df_wo[feat], bins=50)
        axes[0+row, plot_col].set_title("{}".format(feat))
        sns.despine(ax=axes[0+row, plot_col])
        sns.boxplot(data_df_wo[feat], ax=axes[1+row, plot_col], fliersize=2)
        axes[1+row, plot_col].set(yticks=[])
        #axes[1+row, plot_col].set_title("{}".format(data_df[feat].median))
        sns.despine(ax=axes[1+row, plot_col], left=True)

    for ax in axes.flatten():
        ax.set_xlabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visual outliers analysis

# %%
# Plot z-scores
plt.scatter(data_df['Gr Liv Area'], data_df['SalePrice'], c=z_score['Price SF'], cmap='coolwarm')
plt.colorbar()
plt.show()

# %% [markdown]
# ### The 2 houses above 700 k$ are price outliers, but considering the Price per Square feet they are not ! They are just big houses

# %%
# Plot the sane without outliers
plt.scatter(data_df_wo['Gr Liv Area'], data_df_wo['SalePrice'] , c=data_df_wo['Price SF'], cmap='coolwarm')
plt.colorbar()
plt.show()

# %% [raw]
# # Remove low Price per Square Feet
# data_df_wo =  data_df_wo.drop(data_df_wo.loc[(data_df_wo['Price SF']) < 40].index, axis = 0)
# # Remove high Sales Prices above 500k$
# data_df_wo =  data_df_wo.drop(data_df_wo.loc[(data_df_wo['SalePrice']) > 500000].index, axis = 0)
# data_df_wo.shape

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#     Outliers removed
#
# ### Here I removed on both sides the "unusual sale prices" considering the square feet.
#
# ### And here, for example, the 2 houses sold above 700000$ were not we removed not because of the price, or Gr Liv Area, but for other reasons : Lot Frontage, 2nd Flr SF,...

# %%
z_score_df_excl_0.loc[data_df['SalePrice']>700000]
# Out:
#      Lot Frontage  Lot Area  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# 102          True     False         False          True         False
# 237         False     False          True         False         False
#
#      Bsmt Unf SF  Total Bsmt SF  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# 102        False           True        True        True            False
# 237        False           True        True        True            False
#
#      Garage Area  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 102        False         False          False           False       False
# 237        False         False          False           False       False
#
#      Screen Porch  Pool Area  Misc Val  Price SF
# 102         False      False     False     False
# 237         False      False     False     False

# %% [markdown]
# ### As "Price per SF" is dependent on 2 other columns : "SalePrice" and "Gr Liv Area", it does not bring information and bring collinearity, so we can drop it.
# ### We can notice, that other variables can be considered "collinear" as we have almost similar informations : we might need to drop these columns after except if I use a Regularization method, which I will

# %%
data_df_wo= data_df_wo.drop('Price SF', axis = 1);
data_df_wo.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    484  528275070           60        RL          68.0      8795   Pave
# 1   2586  535305120           20        RL          75.0     10170   Pave
# 2   2289  923228250          160        RM          21.0      2001   Pave
# 3    142  535152150           20        RL          70.0     10552   Pave
# 4   2042  903475060          190        RM          60.0     10120   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0    NA       IR1          Lvl  ...         0      NA     NA           NA
# 1    NA       Reg          Lvl  ...         0      NA     NA           NA
# 2    NA       Reg          Lvl  ...         0      NA     NA           NA
# 3    NA       IR1          Lvl  ...         0      NA     NA           NA
# 4    NA       IR1          Bnk  ...         0      NA  MnPrv           NA
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Deeper analytical knowledge : Correlations
# --------------------------------------------------------------------
#
# ### Let's see if these features have a strong "correlation" with the Sale Price.

# %% [markdown]
# ### Continuous features

# %%
df_corr = data_df_wo[continuous_col + ordinal_col + yr_col].corr(method ='pearson').round(2)

plt.figure(figsize=(20, 20))
heatmap = sns.heatmap(df_corr, xticklabels = df_corr.columns, yticklabels = df_corr.columns , annot=True, cmap='RdBu_r')

# %%
df_corr['SalePrice'].sort_values(ascending = False).head(7)
# Out:
# SalePrice        1.00
# Overall Qual     0.81
# Gr Liv Area      0.71
# Garage Cars      0.66
# Garage Area      0.63
# Year Built       0.61
# Total Bsmt SF    0.61
# Name: SalePrice, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#
# ### Let's plot the most correlated columns with Sales Price to have a good understanding of the dataset (Garage Area and Garage cars are supposedly nearly collinear no need to plut them both)
#
#     We will use later, the features for the simple model.

# %%
fig, axes = plt.subplots(nrows=6, ncols=1, figsize=(5, 25))

for col, ax in zip(['Overall Qual','Gr Liv Area','Garage Area', 'Total Bsmt SF', '1st Flr SF','Mas Vnr Area'],axes.ravel()):
    ax.scatter(data_df_wo[col], data_df_wo['SalePrice'])
    ax.set_title(col)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Overall Quality seems to be very well connected to the Sales Price, which makes sense.. we will use this with Gr Liv Area for the simple model.

# %%
sns.scatterplot(data_df_wo['Gr Liv Area'], data_df_wo['SalePrice'], hue = data_df_wo['Overall Qual'])
plt.show()

# %% [markdown]
# ### These are the features I will use in my simple model
#
# ### Age of house ? I suppose it would be interested to look at this engineered feature.

# %%
sns.scatterplot(data_df_wo['Yr Sold']-data_df_wo['Year Built'], data_df_wo['SalePrice'], hue = data_df_wo['Yr Sold']-data_df_wo['Year Built'])
plt.show()

# %%
# Plot age vs Price, depending on Remodeling date
sns.scatterplot(data_df_wo['Yr Sold']-data_df_wo['Year Built'], data_df_wo['SalePrice'], hue = data_df_wo['Year Remod/Add'])
plt.show()

# %% [markdown]
# ### Here we can see an important decorelation between the price and age, it could be interesting to add the feature.

# %% [markdown]
# ### Influence of Categorical features (for Simple and Intermediate models)

# %% [markdown]
# ### Neighborhood

# %%
# Draw Plot
plt.figure(figsize=(23,10), dpi= 80)
sns.boxplot(x= 'Neighborhood', y= 'SalePrice', data = data_df_wo, notch=False)

# %% [markdown]
# ### Other nominal values before one hot encoding

# %%
nominal_col = ['MS SubClass','MS Zoning','Street','Alley','Land Contour','Lot Config','Condition 1','Condition 2','Bldg Type','House Style','Roof Style','Roof Matl','Exterior 1st','Exterior 2nd','Mas Vnr Type','Foundation','Heating','Central Air','Garage Type','Misc Feature','Sale Type','Sale Condition']


# 20 subplots of all continuous data
fig, axes = plt.subplots(
    6, 4 , figsize=(35,35)
)

# pairing feature with column in plot
for i in [0,1,2,3,4,5]:
    for (feat, plot_col) in zip(nominal_col[0+4*i:4+4*i], [0,1,2,3,4] ):

        sns.boxplot(x= feat, y= 'SalePrice', data = data_df_wo, notch=False, ax=axes[0+i, plot_col])
        #axes[0+row, plot_col].set_title("{}".format(feat))
        #sns.despine(ax=axes[0+row, plot_col])


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ordinal columns before "future" feature engineering

# %%
ordinal_col = ['Lot Shape','Utilities','Land Slope','Overall Qual','Overall Cond','Exter Qual','Exter Cond','Bsmt Qual','Bsmt Cond','Bsmt Exposure','BsmtFin Type 1','BsmtFin Type 2','Heating QC','Electrical','Kitchen Qual','Functional','Fireplace Qu','Garage Finish','Garage Qual','Garage Cond','Paved Drive','Pool QC','Fence','Bsmt Full Bath','Bsmt Half Bath','Full Bath','Half Bath','Bedroom AbvGr','Kitchen AbvGr','TotRms AbvGrd','Fireplaces','Garage Cars']

fig, axes = plt.subplots(
    8, 4 , figsize=(35,35)
)

# pairing feature with column in plot
for i in [0,1,2,3,4,5,6,7]:
    for (feat, plot_col) in zip(ordinal_col[0+4*i:4+4*i], [0,1,2,3,4] ):

        sns.boxplot(x= feat, y= 'SalePrice', data = data_df_wo, notch=False, ax=axes[0+i, plot_col])
        #axes[0+row, plot_col].set_title("{}".format(feat))
        #sns.despine(ax=axes[0+row, plot_col])


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Remarque : Overall Cond = 5 seems to have a lot more variability and wide range than the other, possible a feature not well understood compared to Overall Quality ?

# %% [markdown]
# # Feature Engineering : Ordinal Encoding

# %% [markdown]
# ### Let's encode ordinal columns based on the documentation.txt and what I would consider more important or valuable in a property

# %%
# Print each value for all ordinal columns
for col in ordinal_col:
    print(col,' :',data_df_wo[col].unique())
# Out:
# Lot Shape  : ['IR1' 'Reg' 'IR2' 'IR3']
# Utilities  : ['AllPub' 'NoSeWa' 'NoSewr']
# Land Slope  : ['Gtl' 'Mod' 'Sev']
# Overall Qual  : [ 7  6  4  5  8  9  3  1  2 10]
# Overall Cond  : [5 6 4 8 7 9 3 2 1]
# Exter Qual  : ['Gd' 'TA' 'Fa' 'Ex']
# Exter Cond  : ['TA' 'Gd' 'Fa' 'Ex' 'Po']
# Bsmt Qual  : ['Gd' 'TA' 'Ex' 'NA' 'Fa' 'Po']
# Bsmt Cond  : ['TA' 'Gd' 'Fa' 'NA' 'Ex' 'Po']
# Bsmt Exposure  : ['No' 'Av' 'Mn' 'Gd' 'NA']
# BsmtFin Type 1  : ['GLQ' 'Unf' 'Rec' 'LwQ' 'BLQ' 'ALQ' 'NA']
# BsmtFin Type 2  : ['Unf' 'LwQ' 'BLQ' 'NA' 'Rec' 'ALQ' 'GLQ']
# Heating QC  : ['Ex' 'TA' 'Fa' 'Gd' 'Po']
# Electrical  : ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix']
# Kitchen Qual  : ['Gd' 'TA' 'Ex' 'Fa' 'Po']
# Functional  : ['Typ' 'Mod' 'Min2' 'Min1' 'Maj1' 'Maj2' 'Sev']
# Fireplace Qu  : ['TA' 'Gd' 'NA' 'Fa' 'Po' 'Ex']
# Garage Finish  : ['Fin' 'Unf' 'RFn' 'NA']
# Garage Qual  : ['TA' 'Fa' 'NA' 'Ex' 'Gd' 'Po']
# Garage Cond  : ['TA' 'NA' 'Fa' 'Gd' 'Ex' 'Po']
# Paved Drive  : ['Y' 'N' 'P']
# ...

# %%
# create a mapping based on "personal" values : example, better to have "all utilities" = 8,  much more valuable than no Sewer and no water = 3

map_ordinal =  [{"col":"Lot Shape", "mapping": {'Reg':1, 'IR1':3, 'IR2':4, 'IR3':2  }},
                {"col":"Utilities", "mapping": {'AllPub':8, 'NoSewr':6, 'NoSeWa':3, 'ELO':1  }},
                {"col":"Land Slope","mapping": {'Gtl':5, 'Mod':3, 'Sev':1  }},
                {"col":"Exter Qual","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1  }},
                {"col":"Exter Cond","mapping": {'Ex':5,'Gd':4, 'TA':3, 'Fa':2, 'Po':1  }},
                {"col":"Bsmt Qual", "mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0  }},
                {"col":"Bsmt Cond", "mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0  }},
                {"col":"Bsmt Exposure","mapping": {'Gd':5, 'Av':4, 'Mn':3, 'No':1, 'NA':0  }},
                {"col":"BsmtFin Type 1","mapping": {'GLQ':8, 'ALQ':6, 'BLQ':4, 'Rec':3, 'LwQ':2, 'Unf':1, 'NA':0  }},
                {"col":"BsmtFin Type 2","mapping": {'GLQ':8, 'ALQ':6, 'BLQ':4, 'Rec':3, 'LwQ':2, 'Unf':1, 'NA':0  }},
                {"col":"Heating QC","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1  }},
                {"col":"Electrical","mapping": {'SBrkr':5, 'FuseA':4, 'FuseF':3, 'FuseP':2, 'Mix':1  }},
                {"col":"Kitchen Qual","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1  }},
                {"col":"Functional","mapping": {'Typ':10, 'Min1':9, 'Min2':8, 'Mod':7, 'Maj1':5, 'Maj2':4, 'Sev':2, 'Sal':1 }},
                {"col":"Fireplace Qu","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0  }},
                {"col":"Garage Finish", "mapping": {'Fin':5, 'RFn':3, 'Unf':1, 'NA':0  }},
                {"col":"Garage Qual","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0  }},
                {"col":"Garage Cond","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0  }},
                {"col":"Paved Drive","mapping": {'Y':5, 'P':3, 'N':1  }},
                {"col":"Pool QC","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'NA':0 }},
                {"col":"Fence","mapping": {'GdPrv':5, 'MnPrv':4, 'GdWo':3, 'MnWw':2, 'NA':0  }}]

# %% [markdown]
# ### I installed another category_encoders which can use "mapping" : conda install -c conda-forge category_encoders
#
# Scikit learn OrdinalEncoder seems less practical for the mapping and returns a dataframe, found this one here : https://github.com/scikit-learn-contrib/category_encoders/issues/228

# %%
from category_encoders.ordinal import OrdinalEncoder

# Handle ordinal variables
ordinal_encoder = OrdinalEncoder(mapping = map_ordinal, 
                         return_df = True)  

# returns df

# %% [markdown]
# ### Let's check ordinal features again after encoding

# %%
# Plotting to check if my mapping choice is consistent compared to the Prices
ordinal_encoded_df = ordinal_encoder.fit_transform(data_df_wo)

# %%
fig, axes = plt.subplots(
    8, 4 , figsize=(45,45)
)

# pairing feature with column in plot
for i in [0,1,2,3,4,5,6,7]:
    for (feat, plot_col) in zip(ordinal_col[0+4*i:4+4*i], [0,1,2,3,4] ):

        sns.boxplot(x= feat, y= 'SalePrice', data = ordinal_encoded_df, notch=False, ax=axes[0+i, plot_col])
        #axes[0+row, plot_col].set_title("{}".format(feat))
        #sns.despine(ax=axes[0+row, plot_col])


plt.tight_layout()
plt.show()

# %% [markdown]
# ### One hot encoding

# %%
from sklearn.preprocessing import OneHotEncoder as ohe
from sklearn.compose import ColumnTransformer

# Handle nominal variables
nominal_transformer = ohe(handle_unknown='ignore', sparse = False)


# returns array

# %%
from category_encoders.one_hot import OneHotEncoder as ohe2
nominal_transformer2 = ohe2(handle_unknown='ignore', return_df = True , use_cat_names = True, drop_invariant = True)
# returns df

# %% [markdown]
# ### Age of house - Feature Engineering

# %%
# Create a function to be integrated in a FunctionTransformer and used in the 3 Model Pipelines to calculate age of the house when Sold and if a house is recent instead of year built

def age(df):
    # Work on a copy
    df = df.copy()


    # calculate age & integrate binary recent house :
    if 'Year Built' in df.columns and 'Yr Sold' in df.columns:
        df['Age'] = df['Yr Sold']-df['Year Built']
        
        #binary recent house ?
        df.loc[df['Year Built']>2000,'Recent House'] = 1
        df.loc[df['Year Built']<=2000,'Recent House'] = 0

    
    return df

# %% [markdown]
# ### Fill Nan

# %%
# Create a function to be integrated in a FunctionTransformer and used in the 3 Model Pipelines.

def fill_na(df):
    # Work on a copy
    df = df.copy()

   
    # Missing values in continuous features
    col_nan_to_na = [x for x in df.columns if x in col_with_nan if x not in ['Electrical','Lot Frontage','Mas Vnr Area','Garage Area','Garage Cars', 'Garage Yr Blt','Bsmt Full Bath','Bsmt Half Bath','Total Bsmt SF','Bsmt Unf SF','BsmtFin SF 2','BsmtFin SF 1']]

    for col in col_nan_to_na:
        if col == 'Mas Vnr Type':
            df[col] = df[col].fillna('None')
        else:
            df[col] = df[col].fillna('NA') # replace by existing "NA" in documentation
    
    
    # Replace NaN by 0 (columns in the dataframe columns and in the below list)
    col_nan_to_0 = [x for x in df.columns if x in ['Mas Vnr Area','Garage Area','Garage Cars', 'Bsmt Full Bath','Bsmt Half Bath','Total Bsmt SF','Bsmt Unf SF','BsmtFin SF 2','BsmtFin SF 1']]

    for col in col_nan_to_0:
        df[col] = df[col].fillna(0) # replace by 0 as it represents a "number"

    # Replace NaN by other value 

    # by most frequent value
    if 'Electrical' in df.columns:
        df['Electrical'] = df['Electrical'].fillna(df['Electrical'].value_counts().idxmax())

    # by median value
    if 'Lot Frontage' in df.columns:
        df['Lot Frontage'] = df['Lot Frontage'].fillna(df['Lot Frontage'].median())

    # by "No garage" or 0 ?
    if 'Garage Yr Blt' in df.columns:
        df['Garage Yr Blt'] = df['Garage Yr Blt'].fillna(0)


    
    return df

# %% [markdown]
# # Split data

# %%
# Split into train/test sets

train_df, test_df = train_test_split(data_df_wo, train_size=0.5, test_size=0.5, random_state=0)

# Create X/y variables

X = data_df_wo.drop('SalePrice', axis=1)
y = np.log1p(data_df_wo['SalePrice'])


X_tr = train_df.drop('SalePrice', axis=1)
y_tr = np.log1p(train_df['SalePrice'])

X_te = test_df.drop('SalePrice', axis=1)
y_te = np.log1p(test_df['SalePrice'])

# %% [markdown]
# # Create a pipeline that can be used for all three "models" : simple, intermediate and complex

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import FunctionTransformer
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# # Complex model
# -------------------
#
# ### I chose to start with the complex model with all the features in one pipeline and use grid search and cross-validation with 10 split sets, and then slightly modify it for the simple and intermediate models.

# %%
map_ordinal_complex =  [{"col":"Lot Shape", "mapping": {'Reg':1, 'IR1':3, 'IR2':4, 'IR3':2  }},
                {"col":"Utilities", "mapping": {'AllPub':8, 'NoSewr':6, 'NoSeWa':3, 'ELO':1  }},
                {"col":"Land Slope","mapping": {'Gtl':5, 'Mod':3, 'Sev':1  }},
                {"col":"Exter Qual","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1  }},
                {"col":"Exter Cond","mapping": {'Ex':5,'Gd':4, 'TA':3, 'Fa':2, 'Po':1  }},
                {"col":"Bsmt Qual", "mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0  }},
                {"col":"Bsmt Cond", "mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0  }},
                {"col":"Bsmt Exposure","mapping": {'Gd':5, 'Av':4, 'Mn':3, 'No':1, 'NA':0  }},
                {"col":"BsmtFin Type 1","mapping": {'GLQ':8, 'ALQ':6, 'BLQ':4, 'Rec':3, 'LwQ':2, 'Unf':1, 'NA':0  }},
                {"col":"BsmtFin Type 2","mapping": {'GLQ':8, 'ALQ':6, 'BLQ':4, 'Rec':3, 'LwQ':2, 'Unf':1, 'NA':0  }},
                {"col":"Heating QC","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1  }},
                {"col":"Electrical","mapping": {'SBrkr':5, 'FuseA':4, 'FuseF':3, 'FuseP':2, 'Mix':1  }},
                {"col":"Kitchen Qual","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1  }},
                {"col":"Functional","mapping": {'Typ':10, 'Min1':9, 'Min2':8, 'Mod':7, 'Maj1':5, 'Maj2':4, 'Sev':2, 'Sal':1 }},
                {"col":"Fireplace Qu","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0  }},
                {"col":"Garage Finish", "mapping": {'Fin':5, 'RFn':3, 'Unf':1, 'NA':0  }},
                {"col":"Garage Qual","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0  }},
                {"col":"Garage Cond","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0  }},
                {"col":"Paved Drive","mapping": {'Y':5, 'P':3, 'N':1  }},
                {"col":"Pool QC","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'NA':0 }},
                {"col":"Fence","mapping": {'GdPrv':5, 'MnPrv':4, 'GdWo':3, 'MnWw':2, 'NA':0  }}]

# %%
# I created Pipeline imbricated in column transformer into another pipeline like found here : https://towardsdatascience.com/pipeline-columntransformer-and-featureunion-explained-f5491f815f

### Modify list of columns if necessary (depends on the complexity of the model) 

continuous_col_ex_y_complex = ['Lot Frontage','Lot Area', 'Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Unf SF','Total Bsmt SF','1st Flr SF','2nd Flr SF','Low Qual Fin SF','Gr Liv Area','Garage Area','Wood Deck SF','Open Porch SF','Enclosed Porch','3Ssn Porch','Screen Porch','Pool Area','Misc Val']

ordinal_col_complex = ['Lot Shape','Utilities','Land Slope','Overall Qual','Overall Cond','Exter Qual','Exter Cond','Bsmt Qual','Bsmt Cond','Bsmt Exposure','BsmtFin Type 1','BsmtFin Type 2','Heating QC','Electrical','Kitchen Qual','Functional','Fireplace Qu','Garage Finish','Garage Qual','Garage Cond','Paved Drive','Pool QC','Fence','Bsmt Full Bath','Bsmt Half Bath','Full Bath','Half Bath','Bedroom AbvGr','Kitchen AbvGr','TotRms AbvGrd','Fireplaces','Garage Cars']

# year including feature "Age"
yr_col_complex = ['Year Built','Year Remod/Add','Garage Yr Blt','Yr Sold','Mo Sold','Age','Recent House']

nominal_col_complex = ['MS SubClass','MS Zoning','Street','Alley','Land Contour','Lot Config','Neighborhood','Condition 1','Condition 2','Bldg Type','House Style','Roof Style','Roof Matl','Exterior 1st','Exterior 2nd','Mas Vnr Type','Foundation','Heating','Central Air','Garage Type','Misc Feature','Sale Type','Sale Condition']

# alpha chosen by default
alpha = 0.001


# FunctionTransformer = fill na with columns specified in the function fill_na
fill_na_pipe = FunctionTransformer(fill_na, validate=False)

# FunctionTransformer = calculate age
age_pipe = FunctionTransformer(age, validate=False)

# Define pipeline for Years
year_pipe = Pipeline([('imputer', SimpleImputer(strategy='constant', fill_value = 0)),
                     ('years', FunctionTransformer(lambda X: X))])



# Define categorical pipeline for one hot encoding
nominal_pipe = Pipeline([('ohe', ohe(handle_unknown='ignore', sparse = False))])

# Define categorical pipeline for ordinal encoding as defined with the former mapping = map_ordinal
ordinal_pipe = Pipeline([('ordinal', OrdinalEncoder(mapping = map_ordinal_complex, return_df = True) )])

# Define numerical pipeline (simple imputer + log1p + polynomial + Standard Scaler) 
num_pipe = Pipeline([('imputer', SimpleImputer(strategy='median')),
                     ('log_poly', FunctionTransformer(lambda X: np.c_[X, np.log1p(X), X**2, X**0.5])),
                     ('scaler', StandardScaler())])

# Combine categorical and numerical pipelines => 78 input columns to 294 (contiuous 19 to 76 columns, nominal 23 to 181, ordinal 32 to 32, 4 years columns)
preprocessor_complex = ColumnTransformer(transformers=[('nom', nominal_pipe, nominal_col_complex),
                                               ('ord', ordinal_pipe, ordinal_col_complex),
                                               ('year', year_pipe, yr_col_complex),
                                               ('num', num_pipe, continuous_col_ex_y_complex)])


# Fit a pipeline with transformers and an estimator to the training data
pipe_complex = Pipeline(steps=[('fill na', fill_na_pipe),
                       ('age', age_pipe),
                       ('preprocessor', preprocessor_complex),
                       ('model', Ridge(alpha = alpha, tol = 1e-6))])
# alpha = alpha, tol = 1e-6
### I have to modify the Ordinal Pipeline parameter ( = mapping) to match the ordinal columns chosen:
pipe_complex.set_params(preprocessor__ord__ordinal__mapping = map_ordinal_complex)



# I choose ridge estimator because lasso seems to under-evaluate the impact of some features.

pipe_complex.fit(X_tr, y_tr)



# Predict training data, invert log1p with exp1m
y_tr_prev = np.expm1(pipe_complex.predict(X_tr))
print(f"Predictions on train data MAE : " ,MAE(np.expm1(y_tr), y_tr_prev).round(2))

# Predict test data
y_te_prev = np.expm1(pipe_complex.predict(X_te))
print(f"Predictions on test data MAE : ",MAE(np.expm1(y_te), y_te_prev).round(2))
# Out:
# Predictions on train data MAE :  9132.79
# Predictions on test data MAE :  12153.2

# %%
test_age_fit = age_pipe.transform(X_tr)
print(test_age_fit.shape,X_tr.shape)
# Out:
# (1109, 83) (1109, 81)

# %% [markdown]
# ### Cross Validation and Grid Search - COMPLEX
# ----------------------------------

# %%
# Fit/test 20 models (alpha) with 10 different splits
gs_results_complex = []
for run_idx in range(10):
    # Split into train/test sets from the dataframe without outliers
    train_df, test_df = train_test_split(
    data_df_wo, train_size=0.7, test_size=0.3, random_state=run_idx)
    
    # Create X/y variables

    X_te = test_df.drop('SalePrice', axis=1)
    y_te = np.log1p(test_df['SalePrice'])


    X_tr = train_df.drop('SalePrice', axis=1)
    y_tr = np.log1p(train_df['SalePrice'])


    # Grid search 
    for alpha in np.logspace(-3, 4, num=20):
        # modify the pipeline alpha in the Ridge estimator
        pipe_complex.set_params(model__alpha=alpha)
        pipe_complex.fit(X_tr, y_tr)
        
        y_tr_prev = np.expm1(pipe_complex.predict(X_tr))
        y_te_prev = np.expm1(pipe_complex.predict(X_te))

        # Save model and its performance on train/test sets
        gs_results_complex.append({
            'complexity':'complex',
            'alpha': alpha,
            'run_idx': run_idx,
            'train_mae': MAE(np.expm1(y_tr), y_tr_prev),
            'test_mae': MAE(np.expm1(y_te), y_te_prev),
        })

# Convert results to DataFrame
gs_results_complex = pd.DataFrame(gs_results_complex)
gs_results_complex.sort_values(ascending = True, by = ['test_mae']).head()
# Out:
#           alpha complexity  run_idx      test_mae     train_mae
# 172   26.366509    complex        8  10452.087181  10670.094466
# 173   61.584821    complex        8  10482.870826  11054.039212
# 171   11.288379    complex        8  10532.962596  10409.452948
# 170    4.832930    complex        8  10642.393553  10230.898160
# 174  143.844989    complex        8  10658.009356  11563.672437

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Here we see that the best alpha but for one run / split, let's check on the 10 test/train splits (cross validation)
#
#     Looks like the split 8, has a really homogenous distribution between the test and train set.

# %%
# Group the results by alpha

gb_alpha_complex = gs_results_complex.groupby('alpha')

# Compute train/test mean scores with std
mean_tr_complex = gb_alpha_complex.train_mae.mean()
mean_te_complex = gb_alpha_complex.test_mae.mean()
std_tr_complex = gb_alpha_complex.train_mae.std()
std_te_complex = gb_alpha_complex.test_mae.std()
alphas_complex = mean_tr_complex.index.values

# Get entry with the best mean test MAE
best_alpha_complex = mean_te_complex.idxmin()
best_result_complex = gb_alpha_complex.get_group(best_alpha_complex)


# Plot mean scores
plt.plot(np.log10(alphas_complex), mean_tr_complex, label='train')
plt.plot(np.log10(alphas_complex), mean_te_complex, label='test')

# Quantify variance with ± 2 x std curves
plt.fill_between(np.log10(alphas_complex), mean_tr_complex-std_tr_complex, mean_tr_complex+std_tr_complex, alpha=0.2)
plt.fill_between(np.log10(alphas_complex), mean_te_complex-std_te_complex, mean_te_complex+std_te_complex, alpha=0.2)

# Add marker for best score
plt.scatter(np.log10(best_alpha_complex), mean_te_complex.min(), marker='x', c='red', zorder=10)

plt.title('Validation curves with {} runs \n best alpha : {}'.format(len(gs_results_complex.groupby('run_idx')),best_alpha_complex.round(4)))
plt.xlabel('$log_{10}(alpha)$')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Indeed we see a different result considering the 10 splits

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### For alpha < 0.1, we see that the model is overfitting on the training set, alpha > 100 it diverges.

# %% [markdown]
# # Simple model :
# --------------------------------
#
# ### I choose 2 inputs based on my former correlation analysis :
# - Overall Quality
# - Gr Liv Area
#
# And actually, it makes sense to look at the "living area" and Quality overall when buying a house.

# %%
# Let's use the pipeline already defined to do a cross validation + grid search

## Define the columns on which the transformers apply and the estimator

continuous_col_ex_y_simple = ['Gr Liv Area']
ordinal_col_simple = ['Overall Qual']
yr_col_simple = []
nominal_col_simple = []


# Combine categorical and numerical pipelines on the chosen columns
preprocessor_simple = ColumnTransformer(transformers=[('nom', nominal_pipe, nominal_col_simple),
                                               ('ord', ordinal_pipe, ordinal_col_simple),
                                               ('year', year_pipe, yr_col_simple),
                                               ('num', num_pipe, continuous_col_ex_y_simple)])


# Fit a pipeline with transformers and an estimator to the training data
# alpha chosen by default
alpha = 1

# this pipe does not include the fill_na function_transformer as we do not have the right columns :

pipe_simple = Pipeline(steps=[('fill na', fill_na_pipe),
                       ('age', age_pipe),
                       ('preprocessor', preprocessor_simple),
                       ('model', Ridge(alpha = alpha, tol = 1e-6))])

### I have to modify the Ordinal Pipeline parameter ( = mapping) inside the Preprocessor inside the final Pipeline which includes the mapping for Ordinal Values and cannot find those columns in the simple dataset : 
pipe_simple.set_params(preprocessor__ord__ordinal__mapping = [])

pipe_simple.fit(X_tr,y_tr)


# Predict training data, invert log1p with exp1m
y_tr_prev = np.expm1(pipe_simple.predict(X_tr))
print(f"Predictions on train data MAE : " ,MAE(np.expm1(y_tr), y_tr_prev).round(2))

# Predict test data
y_te_prev = np.expm1(pipe_simple.predict(X_te))
print(f"Predictions on test data MAE : ",MAE(np.expm1(y_te), y_te_prev).round(2))
# Out:
# Predictions on train data MAE :  22477.43
# Predictions on test data MAE :  22153.15

# %% [markdown]
# ### Cross Validation and Grid Search - SIMPLE
# ----------------------------------

# %%
# Fit/test 20 models (alpha) with 10 different splits
gs_results_simple = []
for run_idx in range(10):
    
    # Split into train/test sets from the dataframe without outliers
    train_df, test_df = train_test_split(
    data_df_wo, train_size=0.7, test_size=0.3, random_state=run_idx)
    
    # Create X/y split variables ==> no need to choose specific columns as it is already done in the pipeline via the Column transformer

    X_te = test_df.drop('SalePrice', axis=1)
    y_te = np.log1p(test_df['SalePrice'])


    X_tr = train_df.drop('SalePrice', axis=1)
    y_tr = np.log1p(train_df['SalePrice'])


    # Grid search 
    for alpha in np.logspace(-1, 3, num=20):
        # modify the pipeline alpha in the Ridge estimator
        pipe_simple.set_params(model__alpha=alpha)
        pipe_simple.fit(X_tr, y_tr)
        
        y_tr_prev = np.expm1(pipe_simple.predict(X_tr))
        y_te_prev = np.expm1(pipe_simple.predict(X_te))

        # Save model and its performance on train/test sets
        gs_results_simple.append({
            'complexity': 'simple',
            'alpha': alpha,
            'run_idx': run_idx,
            'train_mae': MAE(np.expm1(y_tr), y_tr_prev),
            'test_mae': MAE(np.expm1(y_te), y_te_prev),
        })

# Convert results to DataFrame
gs_results_simple = pd.DataFrame(gs_results_simple)
gs_results_simple.sort_values(ascending = True, by = ['test_mae']).head()
# Out:
#          alpha complexity  run_idx      test_mae     train_mae
# 167   2.976351     simple        8  21082.227511  22924.040728
# 168   4.832930     simple        8  21082.865509  22930.691533
# 166   1.832981     simple        8  21085.269456  22918.108737
# 169   7.847600     simple        8  21086.978652  22935.915719
# 173  54.555948     simple        8  21088.656875  22945.656685

# %%
# Group the results by alpha

gb_alpha_simple = gs_results_simple.groupby('alpha')

# Compute train/test mean scores with std
mean_tr_simple = gb_alpha_simple.train_mae.mean()
mean_te_simple = gb_alpha_simple.test_mae.mean()
std_tr_simple = gb_alpha_simple.train_mae.std()
std_te_simple = gb_alpha_simple.test_mae.std()
alphas_simple = mean_tr_simple.index.values

# Get entry with the best mean test MAE
best_alpha_simple = mean_te_simple.idxmin()
best_result_simple = gb_alpha_simple.get_group(best_alpha_simple)


# Plot mean scores
plt.plot(np.log10(alphas_simple), mean_tr_simple, label='train')
plt.plot(np.log10(alphas_simple), mean_te_simple, label='test')

# Quantify variance with ± 2 x std curves
plt.fill_between(np.log10(alphas_simple), mean_tr_simple-std_tr_simple, mean_tr_simple+std_tr_simple, alpha=0.2)
plt.fill_between(np.log10(alphas_simple), mean_te_simple-std_te_simple, mean_te_simple+std_te_simple, alpha=0.2)

# Add marker for best score
plt.scatter(np.log10(best_alpha_simple), mean_te_simple.min(), marker='x', c='red', zorder=10)

plt.title('Validation curves with {} runs \n best alpha : {}'.format(len(gs_results_simple.groupby('run_idx')),best_alpha_simple.round(4)))
plt.xlabel('$log_{10}(alpha)$')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %% [markdown]
# Much bigger variability in the results between two sets !

# %% [markdown]
# ----------------------------------------------------------

# %% [markdown]
# # Intermediate model : most "complex" as I need to choose which features are more likely to give useful informations
# --------------------------------
#
# ### I choose those inputs based on my former correlation analysis and analyzing all the boxplots for ordinal and nominal features :
#
# - Continuous features : the 5 most correlated
# - Ordinal Features ==> based on the boxplots in the deep analysis:
#     - approx. one for each area of the house (Overall, External, Basement, Kitchen, Bath, Total Rooms, Fireplaces..) if it shows different distributions
# - Nominal Features ==> based on the boxplots in the deep analysis
#     - I chose more specifically what the features which show more dense and specific distributions depending on the labels

# %%
map_ordinal_inter = [
                {"col":"Exter Qual","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1  }},
                {"col":"Bsmt Qual", "mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0  }},
                {"col":"Kitchen Qual","mapping": {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1  }}]

# %%
# I created Pipeline imbricated in column transformer into another pipeline like found here : https://towardsdatascience.com/pipeline-columntransformer-and-featureunion-explained-f5491f815f

# Modify list of columns :

continuous_col_ex_y_inter = ['Gr Liv Area','Garage Area','1st Flr SF','Total Bsmt SF']
ordinal_col_inter = ['Overall Qual','Exter Qual','Bsmt Qual','Kitchen Qual','Full Bath','TotRms AbvGrd','Fireplaces']
yr_col_inter = ['Year Remod/Add','Age','Recent House']
nominal_col_inter = ['MS SubClass','MS Zoning','Street','Neighborhood','Foundation','Heating','Central Air','Garage Type','Sale Type']

# alpha chosen by default
alpha = 1


# Combine categorical and numerical pipelines 
preprocessor_inter = ColumnTransformer(transformers=[('nom', nominal_pipe, nominal_col_inter),
                                               ('ord', ordinal_pipe, ordinal_col_inter),
                                               ('year', year_pipe, yr_col_inter),
                                               ('num', num_pipe, continuous_col_ex_y_inter)])


# Fit a pipeline with transformers and an estimator to the training data
pipe_inter = Pipeline(steps=[('fill na', fill_na_pipe),
                        ('age', age_pipe),
                       ('preprocessor', preprocessor_inter),
                       ('model', Ridge(alpha = alpha, tol = 1e-6))])

### I have to modify the Ordinal Pipeline parameter ( = mapping) to match the ordinal columns chosen:
pipe_inter.set_params(preprocessor__ord__ordinal__mapping = map_ordinal_inter)



# I choose ridge estimator because lasso seems to under-evaluate the impact of some features.
pipe_inter.fit(X_tr, y_tr)



# Predict training data, invert log1p with exp1m
y_tr_prev = np.expm1(pipe_inter.predict(X_tr))
print(f"Predictions on train data MAE : " ,MAE(np.expm1(y_tr), y_tr_prev).round(2))

# Predict test data
y_te_prev = np.expm1(pipe_inter.predict(X_te))
print(f"Predictions on test data MAE : ",MAE(np.expm1(y_te), y_te_prev).round(2))
# Out:
# Predictions on train data MAE :  12845.38
# Predictions on test data MAE :  14230.06

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Above, in my pipeline I used the ColumnTransformer to specify which columns are going to be used in my whole pipeline model.
#
#     Let's check that the preprocessor only takes the columns it is supposed to with the same input (whole dataframe):

# %% [markdown]
# ### Cross Validation and Grid Search - Intermediate
# ----------------------------------

# %%
# Fit/test 20 models (alpha) with 10 different splits
gs_results_inter = []
for run_idx in range(10):
    
    # Split into train/test sets from the dataframe without outliers
    train_df, test_df = train_test_split(
    data_df_wo, train_size=0.7, test_size=0.3, random_state=run_idx)
    
    # Create X/y split variables ==> no need to choose specific columns as it is already done in the pipeline via the Column transformer

    X_te = test_df.drop('SalePrice', axis=1)
    y_te = np.log1p(test_df['SalePrice'])


    X_tr = train_df.drop('SalePrice', axis=1)
    y_tr = np.log1p(train_df['SalePrice'])


    # Grid search 
    for alpha in np.logspace(-2, 2, num=20):
        # modify the pipeline alpha in the Ridge estimator
        pipe_inter.set_params(model__alpha=alpha)
        pipe_inter.fit(X_tr, y_tr)
        
        y_tr_prev = np.expm1(pipe_inter.predict(X_tr))
        y_te_prev = np.expm1(pipe_inter.predict(X_te))

        # Save model and its performance on train/test sets
        gs_results_inter.append({
            'complexity': 'inter',
            'alpha': alpha,
            'run_idx': run_idx,
            'train_mae': MAE(np.expm1(y_tr), y_tr_prev),
            'test_mae': MAE(np.expm1(y_te), y_te_prev),
        })

# Convert results to DataFrame
gs_results_inter = pd.DataFrame(gs_results_inter)
gs_results_inter.sort_values(ascending = True, by = ['test_mae']).head()
# Out:
#         alpha complexity  run_idx      test_mae     train_mae
# 172  3.359818      inter        8  13222.521824  13276.317546
# 165  0.112884      inter        8  13223.592417  13001.385536
# 166  0.183298      inter        8  13223.754775  13019.272056
# 164  0.069519      inter        8  13223.870449  12986.835114
# 171  2.069138      inter        8  13225.446576  13218.242417

# %%
# Group the results by alpha

gb_alpha_inter = gs_results_inter.groupby('alpha')

# Compute train/test mean scores with std
mean_tr_inter = gb_alpha_inter.train_mae.mean()
mean_te_inter = gb_alpha_inter.test_mae.mean()
std_tr_inter = gb_alpha_inter.train_mae.std()
std_te_inter = gb_alpha_inter.test_mae.std()
alphas_inter = mean_tr_inter.index.values

# Get entry with the best mean test MAE
best_alpha_inter = mean_te_inter.idxmin()
best_result_inter = gb_alpha_inter.get_group(best_alpha_inter)


# Plot mean scores
plt.plot(np.log10(alphas_inter), mean_tr_inter, label='train')
plt.plot(np.log10(alphas_inter), mean_te_inter, label='test')

# Quantify variance with ± 2 x std curves
plt.fill_between(np.log10(alphas_inter), mean_tr_inter-std_tr_inter, mean_tr_inter+std_tr_inter, alpha=0.2)
plt.fill_between(np.log10(alphas_inter), mean_te_inter-std_te_inter, mean_te_inter+std_te_inter, alpha=0.2)

# Add marker for best score
plt.scatter(np.log10(best_alpha_inter), mean_te_inter.min(), marker='x', c='red', zorder=10)

plt.title('Validation curves with {} runs \n best alpha : {}'.format(len(gs_results_inter.groupby('run_idx')),best_alpha_inter.round(4)))
plt.xlabel('$log_{10}(alpha)$')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
# 6 columns in Simple Model for X : Overall Qual, Gr Liv Area, log1p(Gr Liv Area), + 3 polynomial (Gr Liv Area)
X_preprocessed_simple = preprocessor_simple.transform(X)
X_preprocessed_simple.shape
# Out:
# (2218, 5)

# %%
# 305 columns with all feature engineering
X_preprocessed_inter = preprocessor_inter.transform(X)
X_preprocessed_inter.shape
# Out:
# (2218, 107)

# %%
# 305 columns with all feature engineering
X_preprocessed_complex = preprocessor_complex.transform(X)
X_preprocessed_complex.shape
# Out:
# (2218, 288)

# %% [markdown]
# # Let's test the 3 models with alpha = best alpha and compare to the supposed prices on the whole dataset :

# %%
# Split into train/test sets

train_df, test_df = train_test_split(data_df_wo, train_size=0.5, test_size=0.5, random_state = 1)

# Create X/y variables

X = data_df_wo.drop('SalePrice', axis=1)
y = np.log1p(data_df_wo['SalePrice'])


X_tr = train_df.drop('SalePrice', axis=1)
y_tr = np.log1p(train_df['SalePrice'])

X_te = test_df.drop('SalePrice', axis=1)
y_te = np.log1p(test_df['SalePrice'])

# %%
# Define the best_alpha for the Ridge estimator in the Pipeline
pipe_complex.set_params(model__alpha=best_alpha_complex)
pipe_complex.set_params(preprocessor__ord__ordinal__mapping = map_ordinal_complex)
pipe_complex.fit(X_tr, y_tr)

# Checking globally on the whole dataset
y_prev = np.expm1(pipe_complex.predict(X))
print(f"Predictions on the whole dataset: ",MAE(np.expm1(y), y_prev).round(2))

# Plot the predictions compared to the real prices
plt.scatter(x = y_prev, y= np.expm1(y),  c= abs(np.expm1(y) - y_prev), cmap='coolwarm')
plt.colorbar()
plt.title('Complex model')
plt.show()
# Out:
# Predictions on the whole dataset:  10752.55

# %%
# Define the best_alpha for the Ridge estimator in the Pipeline ==> Fit on the whole dataset
pipe_inter.set_params(model__alpha=best_alpha_inter);
pipe_inter.set_params(preprocessor__ord__ordinal__mapping = map_ordinal_inter)
pipe_inter.fit(X_tr, y_tr);

# Checking globally on the whole dataset
y_prev = np.expm1(pipe_inter.predict(X))
print(f"Predictions on the whole dataset: ",MAE(np.expm1(y), y_prev).round(2))

# Plot the predictions compared to the real prices
plt.scatter(y_prev, np.expm1(y),  c= abs(np.expm1(y) - y_prev), cmap='coolwarm')
plt.colorbar()
plt.title('Intermediate model')
plt.show()
# Out:
# Predictions on the whole dataset:  13519.5

# %%
# Define the best_alpha for the Ridge estimator in the Pipeline ==> Fit on the whole dataset
pipe_simple.set_params(model__alpha=best_alpha_simple);
pipe_simple.set_params(preprocessor__ord__ordinal__mapping = [])
pipe_simple.fit(X_tr, y_tr);

# Checking globally on the whole dataset
y_prev = np.expm1(pipe_simple.predict(X))
print(f"Predictions on the whole dataset: ",MAE(np.expm1(y), y_prev).round(2))

# Plot the predictions compared to the real prices
plt.scatter(y_prev, np.expm1(y),  c= abs(np.expm1(y) - y_prev), cmap='coolwarm')
plt.colorbar()
plt.title('Simple model')
plt.show()
# Out:
# Predictions on the whole dataset:  22384.28

# %% [markdown]
# ### We can see a wider dispersion when the model is "simpler", let's compare each MAE.
# ### Models Comparison for their respective best alphas in the Ridge function

# %%
# MAE Baseline = Median
MAE(np.expm1(y_te), np.full(y_te.shape, np.median(np.expm1(y_te)))).round(2)
# Out:
# 48308.71

# %%
# Concatenate the dataframe

gs_results_global_best_alpha = pd.concat([gs_results_simple.loc[gs_results_simple['alpha'] == best_alpha_simple],gs_results_inter.loc[gs_results_inter['alpha'] == best_alpha_inter],gs_results_complex.loc[gs_results_complex['alpha'] == best_alpha_complex]])


plt.figure(figsize=(5,5), dpi= 80)
sns.boxplot(x= 'complexity', y= 'test_mae', data = gs_results_global_best_alpha, notch=False)
plt.show()

# %% [markdown]
# ### Indeed I am glad to see finally that my complex model is more accurate than the intermediate one.. even though not that much for 4 times fewer features. (35% less accurate for 75% fewer features)

# %% [markdown]
# # Prediction on the Validation Set :

# %%
data_df_validation = pd.read_csv('house-prices-test.csv')
data_df_validation.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0   2217  909279080           50        RL           NaN     11275   Pave
# 1    837  907126050           20        RL          65.0      9757   Pave
# 2   2397  528144030           60        RL          86.0     11065   Pave
# 3   1963  535452060           20        RL          70.0      7000   Pave
# 4    306  911202100           50   C (all)          66.0      8712   Pave
#
#   Alley Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0   NaN       IR1          HLS  ...            0         0     NaN   NaN
# 1   NaN       Reg          Low  ...           92         0     NaN   NaN
# 2   NaN       IR1          Lvl  ...            0         0     NaN   NaN
# 3   NaN       Reg          Lvl  ...            0         0     NaN  MnWw
# 4  Pave       Reg          HLS  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition
# ...

# %%
# Calculate the Sale Price with each model
y_val_simple = np.expm1(pipe_simple.predict(data_df_validation))
y_val_inter = np.expm1(pipe_inter.predict(data_df_validation))
y_val_complex = np.expm1(pipe_complex.predict(data_df_validation))

# %%
# Add these columns to the DataFrame
data_df_validation['Price_Simple'] = y_val_simple
data_df_validation['Price_Inter'] = y_val_inter
data_df_validation['Price_Complex'] = y_val_complex

# %%
data_df_validation.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0   2217  909279080           50        RL           NaN     11275   Pave
# 1    837  907126050           20        RL          65.0      9757   Pave
# 2   2397  528144030           60        RL          86.0     11065   Pave
# 3   1963  535452060           20        RL          70.0      7000   Pave
# 4    306  911202100           50   C (all)          66.0      8712   Pave
#
#   Alley Lot Shape Land Contour  ... Fence Misc Feature Misc Val Mo Sold  \
# 0   NaN       IR1          HLS  ...   NaN          NaN        0       3
# 1   NaN       Reg          Low  ...   NaN          NaN        0      10
# 2   NaN       IR1          Lvl  ...   NaN          NaN        0      10
# 3   NaN       Reg          Lvl  ...  MnWw          NaN        0       4
# 4  Pave       Reg          HLS  ...   NaN          NaN        0       1
#
#   Yr Sold Sale Type Sale Condition   Price_Simple    Price_Inter  \
# ...

# %%
plt.plot(data_df_validation[['Price_Simple','Price_Inter','Price_Complex']]);

# %%
data_df_validation[['Price_Simple','Price_Inter','Price_Complex']].describe()
# Out:
#         Price_Simple    Price_Inter  Price_Complex
# count     500.000000     500.000000     500.000000
# mean   179365.675235  182543.573539  184126.616359
# std     71390.251678   79151.727538   85409.001576
# min     55674.116618   49370.601242   52936.379092
# 25%    128380.175613  130832.038670  129151.589428
# 50%    160840.333799  162840.692779  162828.922960
# 75%    213804.705515  213926.336461  215899.570110
# max    697344.418020  785090.605935  804857.450269

# %%
### Let's create the 3 csv : 
predictions_df_simple = data_df_validation[['PID','Price_Simple']]
predictions_df_simple = predictions_df_simple.rename(columns={'Price_Simple': 'SalePrice'})

predictions_df_inter = data_df_validation[['PID','Price_Inter']]
predictions_df_inter = predictions_df_inter.rename(columns={'Price_Inter': 'SalePrice'})

predictions_df_complex = data_df_validation[['PID','Price_Complex']]
predictions_df_complex = predictions_df_complex.rename(columns={'Price_Complex': 'SalePrice'});

# %%
predictions_df_simple.to_csv(r'predictions-simple-model.csv', index = False)
predictions_df_inter.to_csv(r'predictions-intermediate-model.csv', index = False)
predictions_df_complex.to_csv(r'predictions-complex-model.csv', index = False)

# %% [raw]
# ### Given MAE on https://p3review.herokuapp.com/
#
#                      Simple model        Intermediate model             Complex model
# MAE ($)                $25,642.68                $17,350.01                $14,282.06
# RMSE                     41268.20                  35241.99                  32848.19
